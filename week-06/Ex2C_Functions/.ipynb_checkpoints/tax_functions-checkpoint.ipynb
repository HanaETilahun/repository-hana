# %% [markdown]
# This lab demonstrates how to create and test tax functions using gross pay and withholding codes.

# %%
def get_soc_sec_tax(gross_pay):
    return gross_pay * 0.062
def get_medicare_tax(gross_pay):
    return gross_pay * 0.0145
def get_federal_tax(gross_pay, withholding_code):
    if withholding_code == 0:
        rate = 0.23
    elif withholding_code == 1:
        rate = 0.21
    elif withholding_code == 2:
        rate = 0.195
    elif withholding_code == 3:
        rate = 0.185
    else:
        rate = 0.18 - ((withholding_code - 4) * 0.005)

    return gross_pay * rate
gross_pay = 750
withholding_code = 0

print(get_soc_sec_tax(gross_pay))
print(get_medicare_tax(gross_pay))
print(get_federal_tax(gross_pay, withholding_code))
gross_pay = 1550
withholding_code = 2

print(get_soc_sec_tax(gross_pay))
print(get_medicare_tax(gross_pay))
print(get_federal_tax(gross_pay, withholding_code))
gross_pay = 1100
withholding_code = 5

print(get_soc_sec_tax(gross_pay))
print(get_medicare_tax(gross_pay))
print(get_federal_tax(gross_pay, withholding_code))
# Out:
# 46.5
# 10.875
# 172.5
# 96.1
# 22.475
# 302.25
# 68.2
# 15.950000000000001
# 192.5

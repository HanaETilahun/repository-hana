# %% [markdown]
# # Exercise 2.A Using built-in functions

# %%
test_name = 'Hana Tilahun'

# %%
def parse_and_display(name):

    # Loop through each character in the name
    for i in range(len(name)):

        # Check for space
        if name[i] == ' ':

            # Split first and last name
            first = name[:i]
            last = name[i+1:]

            # Print results
            print(f"Full name: {name}")
            print(f"First name: {first}")
            print(f"Last name: {last}")

# Call the function
parse_and_display("Hana Tilahun")
# Out:
# Full name: Hana Tilahun
# First name: Hana
# Last name: Tilahun

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
# List of names
test_list = [
    "Grace Flore",
    "Hana Tilahun",
    "Marcus Webb",
    "Priya Sharma"
]

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Grace Flore
# First name: Grace
# Last name: Flore

# %%
parse_and_display(test_list[1])
# Out:
# Full name: Hana Tilahun
# First name: Hana
# Last name: Tilahun

# %%
parse_and_display(test_list[2])
# Out:
# Full name: Marcus Webb
# First name: Marcus
# Last name: Webb

# %%
parse_and_display(test_list[3])
# Out:
# Full name: Priya Sharma
# First name: Priya
# Last name: Sharma

# %%
def parse_and_display2(name):

    # Split name into parts
    parts = name.split()

    # One-word name
    if len(parts) == 1:
        print(f"Full name: {name}")
        print(f"First name: {parts[0]}")

    # Two-word name
    elif len(parts) == 2:
        print(f"Full name: {name}")
        print(f"First name: {parts[0]}")
        print(f"Last name: {parts[1]}")

    # Three-word name
    elif len(parts) == 3:
        print(f"Full name: {name}")
        print(f"First name: {parts[0]}")
        print(f"Middle name: {parts[1]}")
        print(f"Last name: {parts[2]}")

# Test cases
parse_and_display2("Lorde")

print()

parse_and_display2("Billie Eilish")

print()

parse_and_display2("Megan Thee Stallion")
# Out:
# Full name: Lorde
# First name: Lorde
#
# Full name: Billie Eilish
# First name: Billie
# Last name: Eilish
#
# Full name: Megan Thee Stallion
# First name: Megan
# Middle name: Thee
# Last name: Stallion
